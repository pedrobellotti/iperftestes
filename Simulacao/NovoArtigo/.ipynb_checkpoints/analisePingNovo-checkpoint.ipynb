# %%
# Bibliotecas python
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import glob
import os
import re
# %matplotlib inline

# Função para calcular moda.
from scipy import stats

# Formatação dos gráficos
from matplotlib.ticker import FuncFormatter
from matplotlib.legend import Legend

import statsmodels.api as sm
# Out:
# /home/joaovictor/.local/lib/python3.6/site-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
# Configurando o tema do gráfico
myrcs = {"axes.titleweight": "bold", "lines.markersize": 9.0, "lines.linewidth": 2.0, "legend.title_fontsize": 13.75}
sns.set (style="whitegrid", font_scale=1.35, rc=myrcs)
sns.set_palette (sns.color_palette (["#b2df8a", "#33a02c", "#cab2d6", "#6a3d9a"]))
sns.set_palette (sns.color_palette (["#b2df8a", "#33a02c", "#fdbf6f", "#ff7f00"]))
sns.set_palette (sns.color_palette ("Paired"))




# Linhas exibidas por padrão nos dataframes
pd.options.display.min_rows = 20

# %%
#Configurações
# A1 - com switch HW, não podendo aumentar/diminuir número de switches SW (número máximo de SW = 1)
# A5 - com switch HW, podendo aumentar/diminuir número de switches SW (número máximo de SW = 5)
# B - sem switch HW, podendo aumentar/diminuir número de switches SW (número máximo de SW = 5)
# D - com switch HW, não podendo aumentar/diminuir número de switches SW (número de SW fixo em 5)
# E - sem switch HW, não podendo aumentar/diminuir número de switches SW (número de SW fixo em 5)

#Nomes das configurações nos gráficos:
# D = (HW = 1; SW = 5); B = (HW = 0; SW = 1-5); A5 = (HW = 1; SW = 1-5); E = (HW = 0; SW = 5)

# Parâmetros que variam nesta simulação
seeds = [1,2]
cargas = ["50hosts"] #"50hosts", "100hosts",
experimentos = ["a5"]

# Tempo total de simulação
t_sim = 2000

# Intervalo de confiança
confianca = 99

# Imprimir titulos nos gráficos
titulos = False

# Salvar graficos
salvarGraficos = False

# %%
def read_df_saidaStruct ():
    df_carga = []
    for carga in cargas:
        df_exp = []
        for experimento in experimentos:
            df_sed = []
            for seed in seeds:
                df = pd.read_csv ("saidas/ping/"+carga+"/seed"+str(seed)+"/"+experimento+"-"+carga+"-"+str(seed)+"-saidaStruct.log", sep='\s+', index_col=["Cookie"])
                df_sed.append (df)
            df_exp.append(pd.concat (df_sed, keys=seeds))
        df_carga.append (pd.concat (df_exp, keys=experimentos))
    df_read = pd.concat (df_carga, keys=cargas, names=["Load","Experimento","Seed","Cookie"], copy=False)
    df_read.rename({"50hosts": "Low", "100hosts": "Medium", "150hosts": "High"}, inplace=True)
    return df_read

def read_df_cache ():
    df_carga = []
    for carga in cargas:
        df_exp = []
        for experimento in experimentos:
            df_sed = []
            for seed in seeds:
                df = pd.read_csv ("saidas/ping/"+carga+"/seed"+str(seed)+"/"+experimento+"-"+carga+"-"+str(seed)+"-traffic-qos-l7-app.log", sep='\s+', index_col=["Teid"])
                df_sed.append (df)
            df_exp.append(pd.concat (df_sed, keys=seeds))
        df_carga.append (pd.concat (df_exp, keys=experimentos))
    df_read = pd.concat (df_carga, keys=cargas, names=["Load","Experimento","Seed","Cookie"], copy=False)
    df_read.rename({"50hosts": "Low", "100hosts": "Medium", "150hosts": "High"}, inplace=True)
    return df_read

def read_df_ping ():
    df_carga = []
    for carga in cargas:
        df_exp = []
        for experimento in experimentos:
            df_sed = []
            for seed in seeds:
                df = pd.read_csv ("saidas/ping/"+carga+"/seed"+str(seed)+"/"+experimento+"-"+carga+"-"+str(seed)+"-pingStats.zip", sep='\s+', compression='zip', index_col=["Cookie"])
                df_sed.append (df)
            df_exp.append(pd.concat (df_sed, keys=seeds))
        df_carga.append (pd.concat (df_exp, keys=experimentos))
    df_read = pd.concat (df_carga, keys=cargas, names=["Load","Experimento","Seed","Cookie"], copy=False)
    df_read.rename({"50hosts": "Low", "100hosts": "Medium", "150hosts": "High"}, inplace=True)
    return df_read

# %%
df_ping = read_df_ping()
#df_ping

# %%
df_saidaStruct = read_df_saidaStruct()
df_saidaStruct.drop(columns=["SRCIP", "DSTIP", "SRCPort", "DSTPort","Protocol","NumSwitches", "Active","Blocked", "Direction", "TimeCreated", "TimeFinished", "ExpBytes", "Rate"],inplace=True)
#df_saidaStruct

# %%
df_concatenado = pd.merge(df_ping, df_saidaStruct, how='left', on = ['Cookie', 'Load','Experimento', 'Seed'])
df_concatenado.reset_index(inplace=True)
#df_concatenado

# %%
df_movido = df_concatenado.query("InCache == 1")
df_movido
# Out:
#                      Cookie Load Experimento  Seed  Time:s   Delay:ns  \
# 0        0x05a059278575a511  Low          a5     1   201.0  1564848.0
# 1        0x05a059278575a511  Low          a5     1   201.0  1564848.0
# 2        0x05a059278575a511  Low          a5     1   201.0  1564848.0
# 3        0x05a059278575a511  Low          a5     1   201.0  1564848.0
# 4        0x05a059278575a511  Low          a5     1   201.1  1564848.0
# 5        0x05a059278575a511  Low          a5     1   201.1  1564848.0
# 6        0x05a059278575a511  Low          a5     1   201.1  1564848.0
# 7        0x05a059278575a511  Low          a5     1   201.1  1564848.0
# 8        0x05a059278575a511  Low          a5     1   201.1  1564848.0
# 9        0x05a059278575a511  Low          a5     1   201.1  1564848.0
# ...                     ...  ...         ...   ...     ...        ...
# 4455670  0x06206127cf75ef11  Low          a5     2   490.8   664848.0
# 4455672  0x06206127cf75ef11  Low          a5     2   490.8   664848.0
# 4455673  0x06206127cf75ef11  Low          a5     2   490.8   664848.0
# 4455674  0x06206127cf75ef11  Low          a5     2   490.8   664848.0
# 4455675  0x06206127cf75ef11  Low          a5     2   490.8   664848.0
# 4455677  0x06206127cf75ef11  Low          a5     2   490.8   664848.0
# 4455678  0x06206127cf75ef11  Low          a5     2   490.9   664848.0
# 4455679  0x06206127cf75ef11  Low          a5     2   490.9   664848.0
# 4455680  0x06206127cf75ef11  Low          a5     2   490.9   664848.0
# 4455682  0x06206127cf75ef11  Low          a5     2   490.9   664848.0
#
#          Jitter:ns  InCache
# 0          97803.0        1
# 1          91690.0        1
# 2          85959.0        1
# 3          80586.0        1
# 4          75549.0        1
# 5          70827.0        1
# 6          66400.0        1
# 7          62250.0        1
# 8          58359.0        1
# 9          54711.0        1
# ...            ...      ...
# 4455670       36.0        1
# 4455672       33.0        1
# 4455673       30.0        1
# 4455674       28.0        1
# 4455675       26.0        1
# 4455677       24.0        1
# 4455678       22.0        1
# 4455679       20.0        1
# 4455680       18.0        1
# 4455682       16.0        1
#
# [3773275 rows x 8 columns]

# %%
df_concatenado = df_concatenado.groupby(["InCache", "Time:s"]).mean()
#df_concatenado = df_concatenado.query("InCache == 0")
df_concatenado.reset_index(inplace = True)
df_concatenado
# Out:
#       InCache  Time:s      Seed      Delay:ns     Jitter:ns
# 0           0   201.4  1.000000  1.564848e+06  97803.000000
# 1           0   201.5  1.000000  1.564848e+06  91690.000000
# 2           0   201.6  1.000000  1.564848e+06  85959.000000
# 3           0   201.7  1.000000  1.564848e+06  97803.000000
# 4           0   201.8  1.000000  1.564848e+06  86138.000000
# 5           0   201.9  1.000000  1.564848e+06  80754.000000
# 6           0   202.0  1.000000  1.564848e+06  75706.500000
# 7           0   202.1  1.750000  1.564848e+06  92239.500000
# 8           0   202.2  1.666667  1.564848e+06  83042.666667
# 9           0   202.3  1.800000  1.564848e+06  79068.000000
# ...       ...     ...       ...           ...           ...
# 5842        1   492.1  1.000000  6.649477e+05    298.900000
# 5843        1   492.2  1.000000  6.648480e+05    164.300000
# 5844        1   492.3  1.000000  6.648480e+05     80.181818
# 5845        1   492.4  1.000000  6.648480e+05     37.200000
# 5846        1   492.5  1.000000  6.648480e+05     16.500000
# 5847        1   492.6  1.000000  6.648480e+05      5.500000
# 5848        1   492.7  1.000000  6.648480e+05      0.000000
# 5849        1   492.8  1.000000  6.648480e+05      0.000000
# 5850        1   492.9  1.000000  6.649205e+05     64.181818
# 5851        1   493.0  1.000000  6.648480e+05     43.200000
#
# [5852 rows x 5 columns]

# %%
snsplt = sns.relplot( x="Time:s", y="Delay:ns", hue="InCache", kind="line", legend=False, 
                      data=df_concatenado, ci=confianca, markers=True)
snsplt.set_titles("title")
snsplt.set_axis_labels("Time", "Delay")
if (titulos):
    snsplt.fig.suptitle('title', y=1.05)
#snsplt.set(ylim=(0,2))
#snsplt.set_xticklabels(rotation=45, size=12)
snsplt.fig.set_size_inches(11,4)
snsplt.despine(left=True)

if (salvarGraficos):
    snsplt.savefig("nome.pdf")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-20-ec49556c17de> in <module>
#      16 order = [0,1,2]
#      17 handles, labels = snsplt.ax.get_legend_handles_labels()
# ---> 18 snsplt.ax.legend([handles[idx] for idx in order],[labels[idx] for idx in order],loc="upper right", title="InCache")
#      19
#      20 if (salvarGraficos):
#
# <ipython-input-20-ec49556c17de> in <listcomp>(.0)
#      16 order = [0,1,2]
#      17 handles, labels = snsplt.ax.get_legend_handles_labels()
# ---> 18 snsplt.ax.legend([handles[idx] for idx in order],[labels[idx] for idx in order],loc="upper right", title="InCache")
#      19
#      20 if (salvarGraficos):
#
# IndexError: list index out of range

# %%
snsplt = sns.relplot( x="Time:s", y="Jitter:ns", hue="InCache", kind="line", legend=False, 
                      data=df_concatenado, ci=confianca, markers=True)
snsplt.set_titles("title")
snsplt.set_axis_labels("Time", "Delay")
if (titulos):
    snsplt.fig.suptitle('title', y=1.05)
#snsplt.set(ylim=(0,2))
#snsplt.set_xticklabels(rotation=45, size=12)
snsplt.fig.set_size_inches(11,4)
snsplt.despine(left=True)

if (salvarGraficos):
    snsplt.savefig("nome.pdf")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-21-47dfc3020738> in <module>
#      16
#      17 handles, labels = snsplt.ax.get_legend_handles_labels()
# ---> 18 snsplt.ax.legend([handles[idx] for idx in order],[labels[idx] for idx in order],loc="upper right", title="InCache")
#      19
#      20 if (salvarGraficos):
#
# <ipython-input-21-47dfc3020738> in <listcomp>(.0)
#      16
#      17 handles, labels = snsplt.ax.get_legend_handles_labels()
# ---> 18 snsplt.ax.legend([handles[idx] for idx in order],[labels[idx] for idx in order],loc="upper right", title="InCache")
#      19
#      20 if (salvarGraficos):
#
# IndexError: list index out of range
