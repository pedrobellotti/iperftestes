# %%
import pandas as pd
import scipy.stats as st
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#df = pd.read_csv("iperf.csv", index_col = [1])
df = pd.read_csv("teste1.csv")
#Remove colunas desnecessarias
del df['Timestamp']
del df['?']
del df['ForaOrdem']
del df['Tempo']
df
# Out:
#         IpOri  PortaOri    IpDest  PortaDest  BitsEnv    Banda  Jitter  \
# 0    10.1.0.2      5511  10.1.0.1       5011   480690   382974     NaN
# 1    10.1.0.2      5590  10.1.0.1       5090  1190700   950267     NaN
# 2    10.1.0.1      5090  10.1.0.2       5590  1190700   955720  63.029
# 3    10.1.0.1      5011  10.1.0.2       5511   480690   385307  62.589
# 4    10.1.0.2      5548  10.1.0.1       5048   164640   130046     NaN
# 5    10.1.0.1      5048  10.1.0.2       5548   164640   130855   0.081
# 6    10.1.0.2      5527  10.1.0.1       5027    36750    27647     NaN
# 7    10.1.0.1      5027  10.1.0.2       5527    36750    27813   0.053
# 8    10.1.0.2      5558  10.1.0.1       5058   636510   506877     NaN
# 9    10.1.0.2      5510  10.1.0.1       5010   316050   250878     NaN
# 10   10.1.0.1      5058  10.1.0.2       5558   636510   509704   0.099
# 11   10.1.0.1      5010  10.1.0.2       5510   316050   252204  62.649
# 12   10.1.0.2      5520  10.1.0.1       5020   160230   126975     NaN
# 13   10.1.0.1      5020  10.1.0.2       5520   160230   127703  62.952
# 14   10.1.0.2      5557  10.1.0.1       5057    51450    38911     NaN
# 15   10.1.0.1      5057  10.1.0.2       5557    51450    39112   0.078
# 16   10.1.0.2      5544  10.1.0.1       5044   586530   467965     NaN
# 17   10.1.0.1      5044  10.1.0.2       5544   586530   469747  62.587
# 18   10.1.0.2      5580  10.1.0.1       5080   145530   114687     NaN
# 19   10.1.0.1      5080  10.1.0.2       5580   145530   115094   0.122
# 20   10.1.0.2      5594  10.1.0.1       5094  3676470  2939891     NaN
# 21   10.1.0.1      5094  10.1.0.2       5594  3676470  2950419   0.079
# 22   10.1.0.2      5537  10.1.0.1       5037   690900   550908     NaN
# 23   10.1.0.1      5037  10.1.0.2       5537   690900   552957  62.574
# 24   10.1.0.2      5592  10.1.0.1       5092   152880   120831     NaN
# 25   10.1.0.1      5092  10.1.0.2       5592   152880   121219   0.077
# 26   10.1.0.2      5587  10.1.0.1       5087   917280   732157     NaN
# 27   10.1.0.2      5553  10.1.0.1       5053   682080   543740     NaN
# 28   10.1.0.1      5087  10.1.0.2       5587   917280   735302  62.563
# 29   10.1.0.1      5053  10.1.0.2       5553   682080   546272  62.556
# ..        ...       ...       ...        ...      ...      ...     ...
# 170  10.1.0.2      5503  10.1.0.1       5003   533610   424957     NaN
# 171  10.1.0.1      5003  10.1.0.2       5503   533610   425791  62.543
# 172  10.1.0.2      5560  10.1.0.1       5060    32340    23551     NaN
# 173  10.1.0.1      5060  10.1.0.2       5560    32340    23575   0.034
# 174  10.1.0.2      5516  10.1.0.1       5016    91140    71679     NaN
# 175  10.1.0.1      5016  10.1.0.2       5516    91140    72101  62.528
# 176  10.1.0.2      5518  10.1.0.1       5018    47040    35839     NaN
# 177  10.1.0.1      5018  10.1.0.2       5518    47040    35962   0.075
# 178  10.1.0.2      5562  10.1.0.1       5062   132300   104447     NaN
# 179  10.1.0.1      5062  10.1.0.2       5562   132300   104699  62.530
# 180  10.1.0.2      5551  10.1.0.1       5051  1193640   953338     NaN
# 181  10.1.0.1      5051  10.1.0.2       5551  1193640   959041   0.097
# 182  10.1.0.2      5555  10.1.0.1       5055   236670   187390     NaN
# 183  10.1.0.1      5055  10.1.0.2       5555   236670   188620   0.284
# 184  10.1.0.2      5565  10.1.0.1       5065   351330   279550     NaN
# 185  10.1.0.1      5065  10.1.0.2       5565   351330   280774  62.771
# 186  10.1.0.2      5542  10.1.0.1       5042  1084860   866299     NaN
# 187  10.1.0.1      5042  10.1.0.2       5542  1084860   868654   0.174
# 188  10.1.0.2      5534  10.1.0.1       5034    45570    34815     NaN
# 189  10.1.0.1      5034  10.1.0.2       5534    45570    34896   0.055
# 190  10.1.0.2      5509  10.1.0.1       5009   921690   735227     NaN
# 191  10.1.0.1      5009  10.1.0.2       5509   921690   738465   0.013
# 192  10.1.0.2      5577  10.1.0.1       5077   768810   613371     NaN
# 193  10.1.0.1      5077  10.1.0.2       5577   768810   616254  62.528
# 194  10.1.0.2      5564  10.1.0.1       5064    16170    11759     NaN
# 195  10.1.0.1      5064  10.1.0.2       5564    16170    11806  62.520
# 196  10.1.0.2      5541  10.1.0.1       5041   392490   312317     NaN
# 197  10.1.0.1      5041  10.1.0.2       5541   392490   313151  62.531
# 198  10.1.0.2      5517  10.1.0.1       5017  1255380  1002490     NaN
# 199  10.1.0.1      5017  10.1.0.2       5517  1255380  1008146   0.141
#
#      PctPerdido  PctEnv  %Perda
# 0           NaN     NaN     NaN
# 1           NaN     NaN     NaN
# 2           0.0   810.0     0.0
# 3           0.0   327.0     0.0
# 4           NaN     NaN     NaN
# 5           0.0   112.0     0.0
# 6           NaN     NaN     NaN
# 7           0.0    25.0     0.0
# 8           NaN     NaN     NaN
# 9           NaN     NaN     NaN
# 10          0.0   433.0     0.0
# 11          0.0   215.0     0.0
# 12          NaN     NaN     NaN
# 13          0.0   109.0     0.0
# 14          NaN     NaN     NaN
# 15          0.0    35.0     0.0
# 16          NaN     NaN     NaN
# 17          0.0   399.0     0.0
# 18          NaN     NaN     NaN
# 19          0.0    99.0     0.0
# 20          NaN     NaN     NaN
# 21          0.0  2501.0     0.0
# 22          NaN     NaN     NaN
# 23          0.0   470.0     0.0
# 24          NaN     NaN     NaN
# 25          0.0   104.0     0.0
# 26          NaN     NaN     NaN
# 27          NaN     NaN     NaN
# 28          0.0   624.0     0.0
# 29          0.0   464.0     0.0
# ..          ...     ...     ...
# 170         NaN     NaN     NaN
# 171         0.0   363.0     0.0
# 172         NaN     NaN     NaN
# 173         0.0    22.0     0.0
# 174         NaN     NaN     NaN
# 175         0.0    62.0     0.0
# 176         NaN     NaN     NaN
# 177         0.0    32.0     0.0
# 178         NaN     NaN     NaN
# 179         0.0    90.0     0.0
# 180         NaN     NaN     NaN
# 181         0.0   812.0     0.0
# 182         NaN     NaN     NaN
# 183         0.0   161.0     0.0
# 184         NaN     NaN     NaN
# 185         0.0   239.0     0.0
# 186         NaN     NaN     NaN
# 187         0.0   738.0     0.0
# 188         NaN     NaN     NaN
# 189         0.0    31.0     0.0
# 190         NaN     NaN     NaN
# 191         0.0   627.0     0.0
# 192         NaN     NaN     NaN
# 193         0.0   523.0     0.0
# 194         NaN     NaN     NaN
# 195         0.0    11.0     0.0
# 196         NaN     NaN     NaN
# 197         0.0   267.0     0.0
# 198         NaN     NaN     NaN
# 199         0.0   854.0     0.0
#
# [200 rows x 10 columns]

# %%
# Função para cálculo do intervalo de confiança de 95%
def confinterval (data):
    confidence = 0.95
    return st.sem (data) * st.t.ppf ((1 + confidence) / 2.0, len (data) - 1);

# %%
#Removendo trafegos pequenos
df = df.query("BitsEnv > 1000000")

gpb = df.groupby (['PortaOri'])
media = gpb.mean()
err = gpb.aggregate(confinterval)
err = err.filter(items=['Banda', 'BitsEnv'])
media = media.filter(items=['Banda', 'BitsEnv'])
#display (media)
#display (err)

media.sort_values(by=["BitsEnv"]).plot (kind='bar', yerr=err, title="Teste", rot=360, figsize=(20,10))
plt.xlabel('Bits enviados')
plt.ylabel('Banda')
plt.gca().legend(('Bits enviados','Banda'))
#plt.savefig('grafico_teste'.pdf')
# Out:
# /home/pedro/anaconda2/lib/python2.7/site-packages/scipy/stats/stats.py:245: RuntimeWarning: The input array could not be properly checked for nan values. nan values will be ignored.
#   "values. nan values will be ignored.", RuntimeWarning)
# /home/pedro/anaconda2/lib/python2.7/site-packages/numpy/core/_methods.py:135: RuntimeWarning: Degrees of freedom <= 0 for slice
#   keepdims=keepdims)
# /home/pedro/anaconda2/lib/python2.7/site-packages/numpy/core/_methods.py:127: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
