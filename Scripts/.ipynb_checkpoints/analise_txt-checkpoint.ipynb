# %%
import pandas as pd
import scipy.stats as st
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
contador = 1
def teste(row):
    global contador
    if (row['Switch'] == 'HW'):
        return contador
    else:
        retorno = contador
        contador += 1
        return retorno

# %%
df = pd.read_table("../Saidas/Teste2/info_parimpar.txt", sep=" ")
df["Medicao"] = df.apply (teste, axis=1)
#df.reset_index().set_index('index', drop=False)
df
# Out:
#     Tempo Switch  RegrasInstaladas  RegrasAceitas  RegrasBloqueadas  \
# 0      15     HW                22            100               596
# 1      15     SW               115            584                 0
# 2      30     HW                41            178               758
# 3      31     SW               141            705                 0
# 4      46     HW                54            230               758
# 5      46     SW               154            769                 0
# 6      61     HW                60            262               758
# 7      61     SW               165            794                 0
# 8      76     HW                63            274               758
# 9      76     SW               157            812                 0
# 10     91     HW                59            285               758
# 11     91     SW               147            840                 0
# 12    106     HW                48            296               758
# 13    106     SW               125            882                 0
# 14    121     HW                44            306               758
# 15    121     SW                85            916                 0
# 16    136     HW                35            319               758
# 17    136     SW                60            937                 0
# 18    151     HW                18            324               758
# 19    151     SW                26            951                 0
# 20    166     HW                11            327               758
# 21    166     SW                25            964                 0
# 22    181     HW                 7            329               758
# 23    181     SW                 8            967                 0
# 24    196     HW                 3            331               758
# 25    196     SW                10            973                 0
# 26    211     HW                 4            332               758
# 27    211     SW                 2            975                 0
#
#     BytesEnviados  Medicao
# 0        39002040        1
# 1       223499304        1
# 2       171379152        2
# 3       958589856        2
# 4       421365672        3
# 5      2252111904        3
# 6       818294400        4
# 7      4092007248        4
# 8      1370853288        5
# 9      6333988752        5
# 10     2016879480        6
# 11     8757206136        6
# 12     2650209408        7
# 13    11043077976        7
# 14     3217720464        8
# 15    12579868728        8
# 16     3702246912        9
# 17    13640332608        9
# 18     3948693840       10
# 19    14107811256       10
# 20     4125423960       11
# 21    14273726040       11
# 22     4266118584       12
# 23    14337553608       12
# 24     4268386584       13
# 25    14383020960       13
# 26     4270746816       14
# 27    14383020960       14

# %%
# Função para cálculo do intervalo de confiança de 95%
def confinterval (data):
    confidence = 0.95
    return st.sem (data) * st.t.ppf ((1 + confidence) / 2.0, len (data) - 1);

# %%
#Agrupando por switch
groups = df.groupby (['Switch'])
#for key,item in gpb:
    #print(gpb.get_group(key), "\n\n")

# Plot
fig, ax = plt.subplots(figsize = (12,7))
#ax.margins(0.05) # Optional, just adds 5% padding to the autoscaling
for name, group in groups:
    ax.plot(group.Tempo, group.RegrasInstaladas, marker='.', linestyle='--', ms=15, label="Switch "+name, alpha=1)
plt.xlabel('Tempo (segundos)')
plt.ylabel('Regras instaladas')
plt.title(u"Regras instaladas nos switches ao longo do tempo - Método Par/Impar") #u = unicode
ax.legend()
plt.savefig('regrasInstaladas_Tempo_ParImpar.pdf')
plt.show()
