# %%
import pandas as pd
import scipy.stats as st
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
contador = 1
def teste(row):
    global contador
    if (row['Switch'] == 'HW'):
        return contador
    else:
        retorno = contador
        contador += 1
        return retorno

# %%
numTeste = "5"
tipoTeste = "sw"
#tipoTeste = "parimpar"
df = pd.read_table("../Saidas/Teste"+numTeste+"/info_"+tipoTeste+".txt", sep=" ")
df["Medicao"] = df.apply (teste, axis=1)
#df.reset_index().set_index('index', drop=False)
#df.drop(df[df.Tempo < 110].index, inplace=True)
#df.drop(df[df.Tempo > 260].index, inplace=True)
df
# Out:
#      Tempo Switch  RegrasInstaladas  RegrasAceitas  VezesBloqueado  \
# 0        8     SW                16             17               0
# 1        8     HW                 2             16               0
# 2       13     HW                16             16               0
# 3       13     SW                48             49               0
# 4       18     HW                16             16               0
# 5       18     SW                70             71               0
# 6       23     HW                66             80               0
# 7       23     SW                74             90               0
# 8       28     HW                65             80               0
# 9       28     SW                89            109               0
# 10      33     HW                83            115               0
# 11      33     SW                57            139               0
# 12      38     HW                78            115               0
# 13      38     SW                81            163               0
# 14      43     HW                86            137               0
# 15      43     SW                91            188               0
# 16      48     HW                70            137               0
# 17      48     SW               125            223               0
# 18      53     HW                91            167               0
# 19      53     SW               126            252               0
# 20      58     HW                78            167               0
# 21      58     SW               163            291               0
# 22      63     HW                95            189               0
# 23      63     SW               170            316               0
# 24      68     HW                75            189               0
# 25      68     SW               196            353               0
# 26      73     HW                93            215               0
# 27      73     SW               195            381               0
# 28      78     HW                74            215               0
# 29      79     SW               220            416               0
# ..     ...    ...               ...            ...             ...
# 115    300     HW                96           1019               0
# 116    302     SW               105           1979               0
# 117    305     HW                60           1019               0
# 118    307     SW               101           1989               0
# 119    310     HW                84           1060               0
# 120    312     SW                63           2000               0
# 121    315     HW                49           1060               0
# 122    317     SW                58           2007               0
# 123    320     HW                97           1111               0
# 124    322     SW                42           2015               0
# 125    325     HW                69           1111               0
# 126    327     SW                41           2021               0
# 127    330     HW                78           1143               0
# 128    332     SW                33           2030               0
# 129    336     HW                39           1143               0
# 130    337     SW                22           2038               0
# 131    341     HW                51           1161               0
# 132    342     SW                 8           2040               0
# 133    346     HW                33           1161               0
# 134    347     SW                 6           2041               0
# 135    351     HW                29           1165               0
# 136    352     SW                 4           2042               0
# 137    356     HW                10           1165               0
# 138    357     SW                 4           2043               0
# 139    361     HW                10           1167               0
# 140    362     SW                 2           2043               0
# 141    366     HW                 5           1167               0
# 142    367     SW                 4           2045               0
# 143    371     HW                 4           1167               0
# 144    372     SW                 4           2045               0
#
#      BytesEnviados  Medicao
# 0          5279904        1
# 1                0        2
# 2         14793408        2
# 3          5279904        2
# 4         43823808        3
# 5         69075720        3
# 6        104058864        4
# 7         69075720        4
# 8        218603448        5
# 9         72397584        5
# 10       367119648        6
# 11        72397584        6
# 12       557683056        7
# 13        74544624        7
# 14       785739528        8
# 15        74544624        8
# 16      1044873648        9
# 17        76962312        9
# 18      1335785472       10
# 19        76962312       10
# 20      1648305288       11
# 21        77760648       11
# 22      1993676328       12
# 23        77760648       12
# 24      2345296464       13
# 25        78469776       13
# 26      2714407416       14
# 27        78469776       14
# 28      3082834944       15
# 29        78519672       15
# ..             ...      ...
# 115    16623439056       58
# 116      141807456       58
# 117    16810423560       59
# 118      183500856       59
# 119    16954495992       60
# 120      183500856       60
# 121    17092993680       61
# 122      963097128       61
# 123    17251056648       62
# 124      963097128       62
# 125    17408284992       63
# 126     1409676912       63
# 127    17549103600       64
# 128     1409676912       64
# 129    17637263784       65
# 130     1623827520       65
# 131    17733824640       66
# 132     1623827520       66
# 133    17832624768       67
# 134     1697245704       67
# 135    17901523584       68
# 136     1697245704       68
# 137    17928028944       69
# 138     1697248728       69
# 139    17934618240       70
# 140     1697248728       70
# 141    17936594424       71
# 142     1697248728       71
# 143    17936594424       72
# 144     1697248728       72
#
# [145 rows x 7 columns]

# %%
# Função para cálculo do intervalo de confiança de 95%
def confinterval (data):
    confidence = 0.95
    return st.sem (data) * st.t.ppf ((1 + confidence) / 2.0, len (data) - 1);

# %%
#Agrupando por switch
groups = df.groupby (['Switch'])
#for key,item in gpb:
    #print(gpb.get_group(key), "\n\n")

# Plot
fig, ax = plt.subplots(figsize = (12,7))
#ax.margins(0.05) # Optional, just adds 5% padding to the autoscaling
for name, group in groups:
    ax.plot(group.Tempo, group.RegrasInstaladas, marker='.', linestyle='--', ms=15, label="Switch "+name, alpha=1)
plt.xlabel('Tempo (segundos)')
plt.ylabel('Regras instaladas')
if(tipoTeste == "parimpar"):
    plt.title(u"Regras instaladas nos switches ao longo do tempo - Método Par/Impar") #u = unicode
else:
    plt.title(u"Regras instaladas nos switches ao longo do tempo - Método SW/HW")
ax.legend()
plt.savefig('regrasInstaladas_Tempo_'+tipoTeste+'_teste'+numTeste+'.pdf')
plt.show()
