# %%
import pandas as pd
import scipy.stats as st
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
contador = 1
def teste(row):
    global contador
    if (row['Switch'] == 'HW'):
        return contador
    else:
        retorno = contador
        contador += 1
        return retorno

# %%
numTeste = "9"
#tipoTeste = "sw"
tipoTeste = "parimpar"
df = pd.read_table("../Saidas/Teste"+numTeste+"/info_"+tipoTeste+".txt", sep=" ")
df["Medicao"] = df.apply (teste, axis=1)
#df.reset_index().set_index('index', drop=False)
df.drop(df[df.Tempo > 80].index, inplace=True)
df
# Out:
#     Tempo Switch  RegrasInstaladas  RegrasAceitas  RegrasBloqueadas  \
# 0       9     SW                45            101                 0
# 1       9     HW                50             97                 0
# 2      14     HW                91            203                 0
# 3      14     SW                91            283                 0
# 4      19     SW               137            428                 0
# 5      19     HW               130            352                 0
# 6      24     HW               135            472               266
# 7      24     SW               160            517                 0
# 8      29     HW               161            589               298
# 9      29     SW               187            612                 0
# 10     34     HW               155            690               382
# 11     35     SW               218            741                 0
# 12     39     HW               161            794               562
# 13     39     SW               244            845                 0
# 14     44     HW               187            870               562
# 15     45     SW               258            913                 0
# 16     49     HW               197            938               594
# 17     52     SW               259           1093                 0
# 18     54     HW               194           1008               636
# 19     55     SW               263           1172                 0
# 20     59     HW               202           1049               636
# 21     61     SW               273           1269                 0
# 22     64     HW               207           1104               640
# 23     64     SW               278           1330                 0
# 24     69     HW               208           1155               688
# 25     71     SW               250           1385                 0
# 26     74     HW               207           1166               688
# 27     74     SW               233           1407                 0
# 28     79     HW               196           1166               688
# 29     79     SW               205           1407                 0
#
#     BytesEnviados  Medicao
# 0        20932128        1
# 1        21595896        2
# 2       110679912        2
# 3       116549496        2
# 4       341037648        3
# 5       326882304        4
# 6       684688032        4
# 7       735308280        4
# 8      1193719464        5
# 9      1325378376        5
# 10     1861217568        6
# 11     2159476200        6
# 12     2692717776        7
# 13     3219087312        7
# 14     3714884208        8
# 15     4514203008        8
# 16     4921443576        9
# 17     6176535120        9
# 18     6273913968       10
# 19     7907433408       10
# 20     7807038120       11
# 21     9914298912       11
# 22     9508317840       12
# 23    12033861336       12
# 24    11371978800       13
# 25    14408806608       13
# 26    13353584832       14
# 27    16910939808       14
# 28    15274426608       15
# 29    19306239624       15

# %%
# Função para cálculo do intervalo de confiança de 95%
def confinterval (data):
    confidence = 0.95
    return st.sem (data) * st.t.ppf ((1 + confidence) / 2.0, len (data) - 1);

# %%
#Agrupando por switch
groups = df.groupby (['Switch'])
#for key,item in gpb:
    #print(gpb.get_group(key), "\n\n")

# Plot
fig, ax = plt.subplots(figsize = (12,7))
#ax.margins(0.05) # Optional, just adds 5% padding to the autoscaling
for name, group in groups:
    ax.plot(group.Tempo, group.RegrasInstaladas, marker='.', linestyle='--', ms=15, label="Switch "+name, alpha=1)
plt.xlabel('Tempo (segundos)')
plt.ylabel('Regras instaladas')
if(tipoTeste == "parimpar"):
    plt.title(u"Regras instaladas nos switches ao longo do tempo - Método Par/Impar") #u = unicode
else:
    plt.title(u"Regras instaladas nos switches ao longo do tempo - Método SW/HW")
ax.legend()
plt.savefig('regrasInstaladas_Tempo_'+tipoTeste+'_teste'+numTeste+'.pdf')
plt.show()
